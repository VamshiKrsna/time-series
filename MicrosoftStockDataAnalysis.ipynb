# %%
import pandas as pd
import pandas_datareader as pdr
import plotly.graph_objects as go
import plotly.express as px
import yfinance as yf

# %%
microsoft = yf.Ticker('MSFT')
microsoft_df = microsoft.history(period='max')
microsoft_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.054791    0.062849    0.054791    0.060163
# 1986-03-14 00:00:00-05:00    0.060163    0.063386    0.060163    0.062311
# 1986-03-17 00:00:00-05:00    0.062311    0.063923    0.062311    0.063386
# 1986-03-18 00:00:00-05:00    0.063386    0.063923    0.061237    0.061774
# 1986-03-19 00:00:00-05:00    0.061774    0.062311    0.060163    0.060700
# ...                               ...         ...         ...         ...
# 2024-04-04 00:00:00-04:00  424.989990  428.670013  417.570007  417.880005
# 2024-04-05 00:00:00-04:00  420.010010  426.510010  418.320007  425.519989
# 2024-04-08 00:00:00-04:00  425.170013  427.279999  423.299988  424.589996
# 2024-04-09 00:00:00-04:00  426.440002  427.739990  421.619995  426.279999
# 2024-04-10 00:00:00-04:00  422.209991  424.029999  419.709991  420.070007
#
#                                Volume  Dividends  Stock Splits
# Date
# ...

# %%
type(microsoft_df)
# Out:
# pandas.core.frame.DataFrame

# %%
microsoft_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9596 entries, 1986-03-13 00:00:00-05:00 to 2024-04-10 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          9596 non-null   float64
#  1   High          9596 non-null   float64
#  2   Low           9596 non-null   float64
#  3   Close         9596 non-null   float64
#  4   Volume        9596 non-null   int64
#  5   Dividends     9596 non-null   float64
#  6   Stock Splits  9596 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 599.8 KB

# %%
microsoft_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  9596.000000  9596.000000  9596.000000  9596.000000  9.596000e+03
# mean     49.910828    50.423081    49.388039    49.926694  5.707284e+07
# std      84.229672    85.042226    83.387247    84.260216  3.814176e+07
# min       0.054791     0.056940     0.054791     0.055866  2.304000e+06
# 25%       3.490529     3.529204     3.422845     3.479651  3.251138e+07
# 50%      19.141928    19.341712    18.924406    19.147149  5.021445e+07
# 75%      36.998368    37.508544    36.687681    37.093710  7.103978e+07
# max     429.829987   430.820007   427.160004   429.369995  1.031789e+09
#
#          Dividends  Stock Splits
# count  9596.000000   9596.000000
# mean      0.002927      0.001772
# std       0.046080      0.058173
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max       3.080000      2.000000

# %%
microsoft_df['Dividends'].value_counts()
# Out:
# Dividends
# 0.00    9515
# 0.13       8
# 0.08       6
# 0.16       5
# 0.36       4
# 0.68       4
# 0.62       4
# 0.56       4
# 0.51       4
# 0.46       4
# 0.42       4
# 0.39       4
# 0.28       4
# 0.31       4
# 0.23       4
# 0.20       4
# 0.11       4
# 0.10       4
# 0.09       3
# 0.75       2
# 3.08       1
# Name: count, dtype: int64

# %%
microsoft_df['Stock Splits'].value_counts()
# Out:
# Stock Splits
# 0.0    9587
# 2.0       7
# 1.5       2
# Name: count, dtype: int64

# %%
microsoft_df.index
# Out:
# DatetimeIndex(['1986-03-13 00:00:00-05:00', '1986-03-14 00:00:00-05:00',
#                '1986-03-17 00:00:00-05:00', '1986-03-18 00:00:00-05:00',
#                '1986-03-19 00:00:00-05:00', '1986-03-20 00:00:00-05:00',
#                '1986-03-21 00:00:00-05:00', '1986-03-24 00:00:00-05:00',
#                '1986-03-25 00:00:00-05:00', '1986-03-26 00:00:00-05:00',
#                ...
#                '2024-03-27 00:00:00-04:00', '2024-03-28 00:00:00-04:00',
#                '2024-04-01 00:00:00-04:00', '2024-04-02 00:00:00-04:00',
#                '2024-04-03 00:00:00-04:00', '2024-04-04 00:00:00-04:00',
#                '2024-04-05 00:00:00-04:00', '2024-04-08 00:00:00-04:00',
#                '2024-04-09 00:00:00-04:00', '2024-04-10 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=9596, freq=None)

# %%
microsoft_df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
microsoft_df.reset_index(inplace=True)
microsoft_df
# Out:
#                           Date        Open        High         Low  \
# 0    1986-03-13 00:00:00-05:00    0.054791    0.062849    0.054791
# 1    1986-03-14 00:00:00-05:00    0.060163    0.063386    0.060163
# 2    1986-03-17 00:00:00-05:00    0.062311    0.063923    0.062311
# 3    1986-03-18 00:00:00-05:00    0.063386    0.063923    0.061237
# 4    1986-03-19 00:00:00-05:00    0.061774    0.062311    0.060163
# ...                        ...         ...         ...         ...
# 9591 2024-04-04 00:00:00-04:00  424.989990  428.670013  417.570007
# 9592 2024-04-05 00:00:00-04:00  420.010010  426.510010  418.320007
# 9593 2024-04-08 00:00:00-04:00  425.170013  427.279999  423.299988
# 9594 2024-04-09 00:00:00-04:00  426.440002  427.739990  421.619995
# 9595 2024-04-10 00:00:00-04:00  422.209991  424.029999  419.709991
#
#            Close      Volume  Dividends  Stock Splits
# 0       0.060163  1031788800        0.0           0.0
# ...

# %%
    fig = go.Figure(data=[go.Candlestick(x=microsoft_df.Date,
                    open=microsoft_df['Open'],
                    high=microsoft_df['High'],
                    low=microsoft_df['Low'],
                    close=microsoft_df['Close'])])

fig.update_layout(title='MSFT Candlestick ',
                  xaxis_title='Date',
                  yaxis_title='Stock Price',
                  xaxis_rangeslider_visible=False)


fig.show()

# %%
fig = go.Figure(data=go.Scatter(x=microsoft_df['Date'],
                                y=microsoft_df['Close'],
                                mode='lines'))

fig.update_layout(title='MSFT Stock Price',
                  xaxis_title='Date',
                  yaxis_title='Stock Price',
                  xaxis_rangeslider_visible=False)

fig.show()

# %%
microsoft_df
# Out:
#                           Date        Open        High         Low  \
# 0    1986-03-13 00:00:00-05:00    0.054791    0.062849    0.054791
# 1    1986-03-14 00:00:00-05:00    0.060163    0.063386    0.060163
# 2    1986-03-17 00:00:00-05:00    0.062311    0.063923    0.062311
# 3    1986-03-18 00:00:00-05:00    0.063386    0.063923    0.061237
# 4    1986-03-19 00:00:00-05:00    0.061774    0.062311    0.060163
# ...                        ...         ...         ...         ...
# 9591 2024-04-04 00:00:00-04:00  424.989990  428.670013  417.570007
# 9592 2024-04-05 00:00:00-04:00  420.010010  426.510010  418.320007
# 9593 2024-04-08 00:00:00-04:00  425.170013  427.279999  423.299988
# 9594 2024-04-09 00:00:00-04:00  426.440002  427.739990  421.619995
# 9595 2024-04-10 00:00:00-04:00  422.209991  424.029999  419.709991
#
#            Close      Volume  Dividends  Stock Splits
# 0       0.060163  1031788800        0.0           0.0
# ...

# %%
microsoft_df['Date'] = pd.to_datetime(microsoft_df['Date'])
microsoft_df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
import datetime as dt

microsoft_df['Year'] = microsoft_df['Date'].dt.year
microsoft_df['Month'] = microsoft_df['Date'].dt.month
microsoft_df['Day'] = microsoft_df['Date'].dt.day

# %%
microsoft_df
# Out:
#            Date        Open        High         Low       Close      Volume  \
# 0    1986-03-13    0.054791    0.062849    0.054791    0.060163  1031788800
# 1    1986-03-14    0.060163    0.063386    0.060163    0.062311   308160000
# 2    1986-03-17    0.062311    0.063923    0.062311    0.063386   133171200
# 60 2023-03-30  281.916229  282.144337  279.188615  281.737671  25053400
# 61 2023-03-31  281.420289  286.915169  280.696221  285.953064  32766000
#
#     Dividends  Stock Splits  Year  Month  Day
# 0         0.0           0.0  2023      1    3
# ...

# %% [markdown]
# Dividends and Stock Splits are not important for forecasting , so drop them.

# %%
tsdata = tsdata.drop(['Dividends', 'Stock Splits'],axis = 1)

# %%
tsdata
# Out:
#          Date        Open        High         Low       Close    Volume  Year  \
# 0  2023-01-03  240.498846  243.140493  234.879151  237.036011  25740000  2023
# 1  2023-01-04  229.813508  230.397239  223.560625  226.667282  50623400  2023
# 2  2023-01-05  224.787446  225.133735  219.405209  219.949371  39585600  2023
# 3  2023-01-06  220.632066  223.362753  217.020830  222.541565  43613600  2023
# 4  2023-01-09  224.045399  228.784544  224.005830  224.708282  27369800  2023
# ..        ...         ...         ...         ...         ...       ...   ...
# 57 2023-03-27  278.216583  279.168760  273.277112  274.130127  26840200  2023
# 58 2023-03-28  273.544941  273.892098  269.835366  272.989502  21878600  2023
# 59 2023-03-29  276.689132  278.851408  276.143621  278.226532  25087000  2023
# 60 2023-03-30  281.916229  282.144337  279.188615  281.737671  25053400  2023
# 61 2023-03-31  281.420289  286.915169  280.696221  285.953064  32766000  2023
#
#     Month  Day
# 0       1    3
# ...

# %%
tsdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    62 non-null     datetime64[ns]
#  1   Open    62 non-null     float64
#  2   High    62 non-null     float64
#  3   Low     62 non-null     float64
#  4   Close   62 non-null     float64
#  5   Volume  62 non-null     int64
#  6   Year    62 non-null     int32
#  7   Month   62 non-null     int32
#  8   Day     62 non-null     int32
# dtypes: datetime64[ns](1), float64(4), int32(3), int64(1)
# memory usage: 3.8 KB

# %%
tsdata.describe()
# Out:
#                                 Date        Open        High         Low  \
# count                             62   62.000000   62.000000   62.000000
# mean   2023-02-16 02:42:34.838709760  252.231843  255.411173  249.579174
# min              2023-01-03 00:00:00  220.632066  223.362753  217.020830
# 25%              2023-01-25 06:00:00  240.590360  243.029193  238.272734
# 50%              2023-02-15 12:00:00  252.215004  254.144154  249.055919
# 75%              2023-03-09 18:00:00  264.361320  270.434551  260.854916
# max              2023-03-31 00:00:00  281.916229  286.915169  280.696221
# std                              NaN   16.155610   16.222083   15.956529
#
#             Close        Volume    Year      Month        Day
# count   62.000000  6.200000e+01    62.0  62.000000  62.000000
# mean   252.708286  3.273071e+07  2023.0   2.048387  15.725806
# min    219.949371  1.734020e+07  2023.0   1.000000   1.000000
# 25%    240.036297  2.602528e+07  2023.0   1.000000   8.250000
# ...

# %%
    fig = go.Figure(data=[go.Candlestick(x=tsdata.Date,
                    open=tsdata['Open'],
                    high=tsdata['High'],
                    low=tsdata['Low'],
                    close=tsdata['Close'])])

fig.update_layout(title='MSFT Candlestick Jan to April 2023',
                  xaxis_title='Date',
                  yaxis_title='Stock Price',
                  xaxis_rangeslider_visible=False)


fig.show()

# %%
fig = go.Figure(data=go.Scatter(x=tsdata['Date'],
                                y=tsdata['Close'],
                                mode='lines'))

fig.update_layout(title='MSFT Stock Price Jan to April 2023 (Line)',
                  xaxis_title='Date',
                  yaxis_title='Stock Price',
                  xaxis_rangeslider_visible=False)

fig.show()

# %% [markdown]
# # Stationarity Test

# %%
tsdata.head()
# Out:
#         Date        Open        High         Low       Close    Volume  Year  \
# 0 2023-01-03  240.498846  243.140493  234.879151  237.036011  25740000  2023
# 1 2023-01-04  229.813508  230.397239  223.560625  226.667282  50623400  2023
# 2 2023-01-05  224.787446  225.133735  219.405209  219.949371  39585600  2023
# 3 2023-01-06  220.632066  223.362753  217.020830  222.541565  43613600  2023
# 4 2023-01-09  224.045399  228.784544  224.005830  224.708282  27369800  2023
#
#    Month  Day
# 0      1    3
# 1      1    4
# 2      1    5
# 3      1    6
# 4      1    9

# %% [markdown]
# # Testing the stationarity of Closing prices.

# %%
from statsmodels.tsa.stattools import adfuller
close_data = tsdata['Close']

# %%
result = adfuller(close_data)

# %%
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
if result[1] <= 0.05:
    print('likely stationary.')
else:
    print('likely non-stationary.')
# Out:
# ADF Statistic: -0.44764459838722254
# p-value: 0.9018347861832158
# Critical Values: {'1%': -3.542412746661615, '5%': -2.910236235808284, '10%': -2.5927445767266866}
# likely non-stationary.

# %% [markdown]
# Hence, Data is Non Stationary

# %% [markdown]
# # Rolling mean, std

# %%
numeric_columns = tsdata.select_dtypes(include=['float64', 'int64'])

moving_mean = numeric_columns.rolling(3).mean()
moving_std = numeric_columns.rolling(3).std()

rolling_results = pd.concat([tsdata['Date'], moving_mean, moving_std], axis=1)

print(rolling_results)
# Out:
#          Date        Open        High         Low       Close        Volume  \
# 0  2023-01-03         NaN         NaN         NaN         NaN           NaN
# 1  2023-01-04         NaN         NaN         NaN         NaN           NaN
# 2  2023-01-05  231.699933  232.890489  225.948328  227.884221  3.864967e+07
# 3  2023-01-06  225.077673  226.297909  219.995554  223.052739  4.460753e+07
# 4  2023-01-09  223.154970  225.760344  220.143956  222.399740  3.685633e+07
# ..        ...         ...         ...         ...         ...           ...
# 57 2023-03-27  276.292385  278.762115  273.091987  275.938629  3.054103e+07
# 58 2023-03-28  275.581552  277.135469  272.050525  275.135223  2.563027e+07
# 59 2023-03-29  276.150219  277.304089  273.085366  275.115387  2.460193e+07
# 60 2023-03-30  277.383434  278.295948  275.055867  277.651235  2.400633e+07
# 61 2023-03-31  280.008550  282.636971  278.676152  281.972422  2.763547e+07
#
#         Open      High       Low     Close        Volume
# ...

# %%
moving_std
# Out:
#         Open      High       Low     Close        Volume
# 0        NaN       NaN       NaN       NaN           NaN
# 1        NaN       NaN       NaN       NaN           NaN
# 2   8.023776  9.258674  8.008531  8.608079  1.246807e+07
# 3   4.597596  3.658890  3.309624  3.388002  5.585623e+06
# 4   2.216177  2.764676  3.550615  2.382623  8.458838e+06
# ..       ...       ...       ...       ...           ...
# 57  1.702181  0.411694  0.165158  2.129724  5.298668e+06
# 58  2.392622  2.838840  1.922072  2.787651  3.316576e+06
# 59  2.381991  2.959128  3.158496  2.754029  2.516115e+06
# 60  4.228612  4.154066  4.770558  4.402368  1.842748e+06
# 61  2.885376  4.054390  2.319161  3.868612  4.443204e+06
#
# [62 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (8,4))
plt.plot(tsdata['Date'], tsdata['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Microsoft Stock Prices Over Time')
plt.xticks(rotation = 45)
plt.show()

# %%
orig = plt.plot(tsdata['Date'], tsdata['Close'], color='blue', label='Original')

mean = plt.plot(rolling_results['Date'], moving_mean['Close'], color='red', label='Rolling Mean')
std = plt.plot(rolling_results['Date'], moving_std['Close'], color='black', label='Rolling Std')

plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.xticks(rotation = 30)

plt.show(block=False)
